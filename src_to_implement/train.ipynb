# %%
# !git clone https://github.com/AaS654/DL_ex4.git
# Out:
# Cloning into 'DL_ex4'...
# remote: Enumerating objects: 2056, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 2056 (delta 10), reused 26 (delta 7), pack-reused 2018 (from 2)
# Receiving objects: 100% (2056/2056), 83.27 MiB | 13.96 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
cd DL_ex4/src_to_implement/
# Out:
# /content/DL_ex4/src_to_implement

# %%
! pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !python PytorchChallengeTests.py Bonus
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 14.180s
#
# OK
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 7.351s
#
# OK
# =========================== Statistics ===============================
# | Pos   | Test           | Result   | Percent       | Percent in Exam   |
# |-------|----------------|----------|---------------|-------------------|
# | 0     | TestDataset    | OK       | 50 / 50 (%)   | 0.750 / 10 (%)    |
# | 1     | TestModel      | OK       | 50 / 50 (%)   | 0.750 / 10 (%)    |
# |       |                |          |               |                   |
# | Ex4   | Total Achieved |          | 100 / 100 (%) | 1.500 / 10 (%)    |

# %%
import torch as t
from data import ChallengeDataset
from trainer import Trainer
from matplotlib import pyplot as plt
import numpy as np
import model
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /content/DL_ex4/src_to_implement/trainer.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
! pip install onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 104.1 MB/s eta 0:00:00
# ...

# %%
# load the data from the csv file and perform a train-test-split
# this can be accomplished using the already imported pandas and sklearn.model_selection modules
# TODO


csv_path = "data.csv"
df = pd.read_csv(csv_path, sep=';')
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)


# set up data loading for the training and validation set each using t.utils.data.DataLoader and ChallengeDataset objects
# TODO
train_dataset = ChallengeDataset(data=train_df, mode='train')
val_dataset = ChallengeDataset(data=val_df, mode='val')


train_loader = t.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = t.utils.data.DataLoader(val_dataset, batch_size=16)

# %%
# create an instance of our ResNet model
# TODO
resnet_model = model.ResNet()

# set up a suitable loss criterion (you can find a pre-implemented loss functions in t.nn)
# set up the optimizer (see t.optim)
# create an object of type Trainer and set its early stopping criterion
# TODO
criterion = t.nn.BCELoss()
optimizer = t.optim.AdamW(resnet_model.parameters(), lr=0.0004, weight_decay=1e-5)

trainer = Trainer(
    model=resnet_model,
    crit=criterion,
    optim=optimizer,
    train_dl=train_loader,
    val_test_dl=val_loader,
    cuda=True,  # Set to True if GPU is available
    early_stopping_patience=16
)

# %%
res = trainer.fit(epochs=50)

# plot the results
plt.plot(np.arange(len(res[0])), res[0], label='train loss')
plt.plot(np.arange(len(res[1])), res[1], label='val loss')
plt.yscale('log')
plt.legend()
plt.savefig('losses.png')
# Out:
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.3185, F1 Score: 0.0952
# 	Train Loss: 0.3358	Val Loss: 0.3185	Val Metric: 0.0952
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.3543, F1 Score: 0.5512
# 	Train Loss: 0.2928	Val Loss: 0.3543	Val Metric: 0.5512
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.3529, F1 Score: 0.3646
# 	Train Loss: 0.2849	Val Loss: 0.3529	Val Metric: 0.3646
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.2805, F1 Score: 0.5903
# 	Train Loss: 0.2617	Val Loss: 0.2805	Val Metric: 0.5903
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.2530, F1 Score: 0.5041
# 	Train Loss: 0.2596	Val Loss: 0.2530	Val Metric: 0.5041
# ...
# Validation/Test:   0%|          | 0/25 [00:00<?, ?it/s]
# Validation Loss: 0.2714, F1 Score: 0.5251
# 	Train Loss: 0.2503	Val Loss: 0.2714	Val Metric: 0.5251
# ...
